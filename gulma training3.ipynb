# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip uninstall keras-nightly
# !pip install h5py==2.10.0
# Out:
# WARNING: Skipping keras-nightly as it is not installed.
# ...

# %%
# !pip install keras==2.1.6
# Out:
# ...
#   Using cached Keras-2.1.6-py2.py3-none-any.whl (339 kB)
# ...
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# ...

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %%
import keras
print(keras.__version__)
# Out:
# 2.1.6
# Using TensorFlow backend.

# %%
import os
os.chdir('/content/drive/MyDrive/Colab/MRCNN_Gulma/')

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab/MRCNN_Gulma

# %%
# Train a new model starting from pre-trained COCO weights
# !python3 gns_new.py train --dataset=datasets/gulmaset3 --weights=last
# Out:
# Using TensorFlow backend.
# Weights:  last
# Dataset:  datasets/gulmaset3
# Logs:  /content/drive/My Drive/Colab/MRCNN_Gulma/logs
#
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        20
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  768
# IMAGE_META_SIZE                18
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [768 768   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# ...

# %%
# Apply color splash to an image
# python3 balloon.py splash --weights=/path/to/weights/file.h5 --image=<URL or path to file>
# !python3 gns_new.py splash --weights=mask_rcnn_gns_0060.h5 --image=images/IMG_20200904_135358.jpg

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('splash_20201022T155601.png')
#print(img)
imgplot = plt.imshow(img)

# %%
from skimage import io
import matplotlib.pyplot as plt

image = io.imread('images/IMG_20200904_135358.jpg')
plt.imshow(image)
plt.show()

imgsplash= io.imread('splash_20201022T155601.png')
plt.imshow(imgsplash)
plt.show()
